# %% [markdown]
# # an example
# * search papers with keywords="physics quantum" and title="physics"
# * and show their titles

# %%
import search_api.open_search_api as search_api

# %%
# for each index one can feed (RELATION, "TERM") tuple
# search result is given with json format
search_result = search_api.search(cql_keywords=("=", "physics quantum"), dc_title=("=", "physics"),
                                  maximum_records=100)

# a sample code to show titles
entry_list = search_result["feed"]["entry"]
for entry in entry_list:
    print(entry["title"])
# Out:
# The <span>physics</span> of <span>quantum</span> materials
# Particle <span>physics</span>: <span>Quantum</span> simulation of fundamental <span>physics</span>
# Atomic <span>physics</span> and <span>quantum</span> optics using superconducting circuits
# <span>Physics</span>: <span>Quantum</span> computing
# <span>Physics</span>: <span>Quantum</span> problems solved through games
# Tomonaga–Luttinger <span>physics</span> in electronic <span>quantum</span> circuits
# <i>H</i>-theorem in <span>quantum</span> <span>physics</span>
# Atomic <span>physics</span>: <span>Quantum</span> theory verified by experiment
# <span>Quantum</span> <span>physics</span>: Frustrated trio mimicked
# <span>Quantum</span> <span>physics</span>: Tailor-made <span>quantum</span> states
# The <span>Quantum</span> <span>Physics</span> of Time Travel
# Probing Planck-scale <span>physics</span> with <span>quantum</span> optics
# Certified randomness in <span>quantum</span> <span>physics</span>
# <span>Physics</span>: <span>Quantum</span> all the way
# <span>Quantum</span> <span>physics</span>: <span>Quantum</span> leaps in the solid state
# Atomic <span>physics</span>: A milestone in <span>quantum</span> computing
# Applied <span>physics</span>: <span>Quantum</span> signals could soon span the globe
# <span>Quantum</span> <span>physics</span>: Watching the wavefunction collapse
# <span>Quantum</span> <span>physics</span>: Photon lab in a circuit
# <span>Physics</span>: <span>Quantum</span> quest
# <span>Quantum</span> <span>physics</span>: Keep your feet on the ground
# Gravitational bar detectors set limits to Planck-scale <span>physics</span> on macroscopic variables
# Supergravity and the Unification of the Laws of <span>Physics</span>
# <span>Quantum</span> <span>physics</span>: Count them all
# <span>Quantum</span> <span>physics</span>: Air juggling and other tricks
# Human mind excels at <span>quantum</span>-<span>physics</span> computer game
# <span>Quantum</span> <span>physics</span>: A grip on misbehaviour
# <span>Quantum</span> simulation of 2D topological <span>physics</span> in a 1D array of optical cavities
# <span>Physics</span>: <span>Quantum</span> outsiders
# Emergent SU(4) Kondo <span>physics</span> in a spin–charge-entangled double <span>quantum</span> dot
# <span>Quantum</span> optics: Gravity meets <span>quantum</span> <span>physics</span>
# <span>Physics</span> Nobel for <span>quantum</span> optics
# Exponential Sensitivity and its Cost in <span>Quantum</span> <span>Physics</span>
# <span>Quantum</span> <span>physics</span>: The path most travelled
# Atomic <span>physics</span>: <span>Quantum</span> leap from light to atoms
# <span>Physics</span>: Unite to build a <span>quantum</span> Internet
# <span>Quantum</span> <span>physics</span>: Tunnelling across a nanowire
# Condensed-matter <span>physics</span>: Magnetic spins that last for ever
# <span>Quantum</span> <span>physics</span>: Wheels within wheels
# Solid-state <span>physics</span>: Join the dots
# <span>Quantum</span> <span>physics</span>: Correlations without parts
# <span>Quantum</span> <span>physics</span>: What is really real?
# Condensed-matter <span>physics</span>: <span>Quantum</span> dots and the Kondo effect
# <span>Quantum</span> <span>physics</span>: Observations turn up the heat
# <span>Quantum</span> <span>physics</span>: NOT logic
# Classical and <span>quantum</span> <span>physics</span> mix
# <span>Quantum</span> gravity: <span>Physics</span> from geometry
# Even-denominator fractional <span>quantum</span> Hall <span>physics</span> in ZnO
# Condensed-matter <span>physics</span>: Coupled vibrations
# Atomic <span>physics</span>: When ultracold is not cold enough
# Optical <span>physics</span>: A larger <span>quantum</span> alphabet
# <span>Quantum</span> <span>physics</span>: Putting a spin on photon entanglement
# <span>Quantum</span> <span>physics</span>:  The philosopher of photons
# Condensed-matter <span>physics</span>: Optical lattices
# Ten years of <i>Nature <span>Physics</span></i>: Jack of all trades
# Supersymmetrical <span>physics</span>
# <span>Quantum</span> <span>physics</span>: A firmer grip on the Hubbard model
# Semiconductor <span>physics</span>: Electrons in artificial atoms
# <span>Quantum</span> <span>physics</span>: Cruise control for a qubit
# <span>Quantum</span> <span>physics</span>: A strong hybrid couple
# <span>Physics</span>: <span>Quantum</span> computer quest
# <span>Quantum</span> <span>physics</span>: Single electrons take the bus
# <span>Quantum</span> <span>physics</span>: Teleportation for two
# <span>Quantum</span> <span>physics</span>:  Push-button teleportation
# <span>Quantum</span> <span>physics</span>: Qubits ride the photon bus
# The new thermodynamics: how <span>quantum</span> <span>physics</span> is bending the rules
# <span>Quantum</span> <span>physics</span>: Photons paired with phonons
# A Unified <span>Physics</span> by 2050?
# A Unified <span>Physics</span> by 2050?
# Theoretical <span>physics</span>: Walk the Planck
# <span>Quantum</span> <span>physics</span>: Simulating magnetism
# <span>Quantum</span> <span>physics</span>: Getting the measure of entanglement
# <span>Physics</span> of life: The dawn of <span>quantum</span> biology
# <span>Quantum</span> <span>physics</span>: Gentle measurement
# <span>Quantum</span> <span>physics</span>: Two-atom bunching
# <span>Quantum</span> <span>physics</span>: Trapped ion set to quiver
# <span>Quantum</span> <span>physics</span>: Atomic envoy enables molecular control
# <span>Quantum</span> <span>physics</span>: Entangled quartet
# Atomic <span>physics</span>: A route to <span>quantum</span> magnetism
# <span>Quantum</span> many-body <span>physics</span>: 2D or not 2D?
# <span>Quantum</span> <span>physics</span>: Disturbance without the force
# <span>Quantum</span> <span>physics</span>: Strongly correlated transport
# Theoretical <span>physics</span>: The emperor's new <span>physics</span>
# Interpretation of <span>Quantum</span> <span>Physics</span>
# Theoretical <span>physics</span>: A black hole full of answers
# <span>Quantum</span> <span>physics</span>: A <i>ménage à trois</i> laid bare
# <span>Physics</span> and applications of exciton–polariton lasers
# Condensed-matter <span>physics</span>: <span>Quantum</span> togetherness
# <span>Quantum</span> <span>physics</span>: A spin solo
# Innovation in <span>Physics</span>
# <span>Physics</span>: QBism puts the scientist back into science
# Fringe <span>physics</span>
# The strange topology that is reshaping <span>physics</span>
# Atomic <span>physics</span>: Atoms playing dress-up
# <span>Quantum</span> <span>physics</span>: Debut of the quarter electron
# Condensed-matter <span>physics</span>: <span>Quantum</span> mechanics in a spin
# Solid-state <span>physics</span>: Drawing <span>quantum</span> circuitry
# <span>Quantum</span> <span>physics</span>: Tangled memories
# Semiconductor <span>physics</span>: One at a time, please
# <span>Quantum</span> <span>physics</span>: <span>Quantum</span> effects of gravity
